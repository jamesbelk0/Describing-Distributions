# %% [markdown]
# # Describing Distributions (Core)
# * James Belk
# * 04/02/2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats
plt.style.use(['seaborn-muted','fivethirtyeight'])
sns.set_context('talk')
medical_data ="Data/data.csv"
df = pd.read_csv(medical_data)
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_123028\3715678405.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(['seaborn-muted','fivethirtyeight'])

# %%
display(df.head())
display(df.info())
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
df['VitD_levels']
# Out:
# 0      19.141466
# 1      18.940352
# 2      18.057507
# 3      16.576858
# 4      17.439069
#          ...
# 995    16.631573
# 996    17.810233
# 997    17.011913
# 998    16.526670
# 999    19.487658
# Name: VitD_levels, Length: 1000, dtype: float64

# %% [markdown]
# ## Histogram with a kde

# %% [markdown]
# ### Vitd_Levels

# %%
mean = df['VitD_levels'].mean()
std = df['VitD_levels'].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
ax = sns.histplot(data=df, x='VitD_levels', stat='probability', kde=True)
ax.axvline(df['VitD_levels'].mean(), color = 'red')
ax.axvline(df['VitD_levels'].median(), color = 'green')
ax.axvline(plus_one_std, color = 'k')
ax.axvline(minus_one_std, color = 'k')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('VitD_levels');

# %%
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# 1. Continuous
# 2. Balanced Skew
# 3. Mesokurtic

# %% [markdown]
# ### Doc_visits

# %%
mean = df['Doc_visits'].mean()
std = df['Doc_visits'].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
ax = sns.histplot(data=df, x='Doc_visits', stat='probability', kde=True)
ax.axvline(df['Doc_visits'].mean(), color = 'red')
ax.axvline(df['Doc_visits'].median(), color = 'green')
ax.axvline(plus_one_std, color = 'k')
ax.axvline(minus_one_std, color = 'k')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('Doc_visits');

# %%
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# 1. Discreate
# 2. Balanced Skew
# 3. Leptokurtic

# %% [markdown]
# ### TotalCharge

# %%
mean = df['TotalCharge'].mean()
std = df['TotalCharge'].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
ax = sns.histplot(data=df, x='TotalCharge', stat='probability', kde=True)
ax.axvline(df['TotalCharge'].mean(), color = 'red')
ax.axvline(df['TotalCharge'].median(), color = 'green')
ax.axvline(plus_one_std, color = 'k')
ax.axvline(minus_one_std, color = 'k')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('TotalCharge');

# %%
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# 1. Continuous
# 2. Skewed to the +1
# 3. Platykurtic
